# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('pic1.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.ones((4,4),np.float32)/16
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x20ca63f1c60>,
#  (np.float64(-0.5), np.float64(287.5), np.float64(511.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('pic.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[1,2,1],[1,-10,1],[1,2,1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x20cfb3d5cf0>,
#  (np.float64(-0.5), np.float64(2975.5), np.float64(3967.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('pic.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x20ca31ba830>,
#  (np.float64(-0.5), np.float64(287.5), np.float64(511.5), np.float64(-0.5)))
