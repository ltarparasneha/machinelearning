# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('flower.jpg',0)
img1=cv2.equalizeHist(img)

plt.subplot(1,2,1),plt.imshow(img,cmap='gray'),plt.title('source image'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1,cmap='gray'),plt.title('equalizeHist image'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'equalizeHist image'}>,
# ...
#  Text(0.5, 1.0, 'equalizeHist image'),
#  (-0.5, 235.5, 212.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('lotus.png')

ycrcb=cv2.cvtColor(img,cv2.COLOR_BGR2YCrCb)

y,cr,cb=cv2.split(ycrcb)

y_eq=cv2.equalizeHist(y)
ycrcb_eq=cv2.merge([y_eq,cr,cb])

global_eq=cv2.cvtColor(ycrcb_eq,cv2.COLOR_BGR2RGB)
source=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
global_eq1=cv2.cvtColor(global_eq,cv2.COLOR_BGR2RGB)

plt.subplot(1,2,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(global_eq1),plt.title('equalizeHist image'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'equalizeHist image'}>,
# ...
#  Text(0.5, 1.0, 'equalizeHist image'),
#  (-0.5, 2499.5, 2499.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('lotus.png')

ycrcb=cv2.cvtColor(img,cv2.COLOR_BGR2YCrCb)

y,cr,cb=cv2.split(ycrcb)

clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
y_clahe=clahe.apply(y)
ycrcb_clahe=cv2.merge((y_clahe,cr,cb))

clahe_eq=cv2.cvtColor(ycrcb_clahe,cv2.COLOR_YCrCb2BGR)
source=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
clahe_eq1=cv2.cvtColor(clahe_eq,cv2.COLOR_BGR2RGB)

plt.subplot(1,2,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(clahe_eq1),plt.title('clahe on color'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'clahe on color'}>,
# ...
#  Text(0.5, 1.0, 'clahe on color'),
#  (-0.5, 2499.5, 2499.5, -0.5))
